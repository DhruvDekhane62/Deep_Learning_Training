# %% [markdown]
# <a href="https://colab.research.google.com/github/DhruvDekhane62/Deep_Learning_Training/blob/main/DL_Training1_Data_Preprocessing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# to remove warnig
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("/content/Data for preprocessing.csv")
data.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4      NaN  40.0      NaN       Yes

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4      NaN  40.0      NaN       Yes

# %%
data.tail()
# Out:
#     Country   Age   Salary Purchased
# 10   France  48.0  79000.0       Yes
# 11  Germany  50.0  83000.0        No
# 12    Spain  27.0  48000.0       Yes
# 13  Germany  50.0  83000.0        No
# 14   France  37.0  67000.0       Yes

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Country    14 non-null     object
#  1   Age        14 non-null     float64
#  2   Salary     14 non-null     float64
#  3   Purchased  15 non-null     object
# dtypes: float64(2), object(2)
# memory usage: 612.0+ bytes

# %%
data.shape
# Out:
# (15, 4)

# %%
data.columns
# Out:
# Index(['Country', 'Age', 'Salary', 'Purchased'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=15, step=1)

# %%
## Handing Duplication

data.duplicated().sum()
# Out:
# np.int64(5)

# %%
data.duplicated().sum()
np.int64(5)
# Out:
# np.int64(5)

# %%
#permant deletion
data.drop_duplicates(inplace=True)

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4      NaN  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#drop irrelevent colomn
data.drop(index=[3,7])
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 4      NaN  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data.isnull().sum()
# Out:
# Country      1
# Age          1
# Salary       1
# Purchased    0
# dtype: int64

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4      NaN  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#delete null rows
#inpalce= True will delete permanantly
data.dropna()
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 5   France  35.0  58000.0       Yes
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
data
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4      NaN  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
#imputation by mean
data["Salary"].fillna(data["Salary"].mean(), inplace=True)
data["Age"].fillna(data["Age"].mean(), inplace=True)

#imputation by mode
data["Country"].fillna(data["Age"].mode()[0], inplace=True)

# %%
data["Salary"].median()
# Out:
# 62388.88888888889

# %%
data["Salary"].mode()
# Out:
# 0    48000.000000
# 1    52000.000000
# 2    54000.000000
# 3    58000.000000
# 4    61000.000000
# 5    63777.777778
# 6    67000.000000
# 7    72000.000000
# 8    79000.000000
# 9    83000.000000
# Name: Salary, dtype: float64

# %%
data
# Out:
#    Country        Age        Salary Purchased
# 0   France  44.000000  72000.000000        No
# 1    Spain  27.000000  48000.000000       Yes
# 2  Germany  30.000000  54000.000000        No
# 3    Spain  38.000000  61000.000000        No
# 4     27.0  40.000000  63777.777778       Yes
# 5   France  35.000000  58000.000000       Yes
# 6    Spain  38.777778  52000.000000        No
# 7   France  48.000000  79000.000000       Yes
# 8  Germany  50.000000  83000.000000        No
# 9   France  37.000000  67000.000000       Yes

# %%
#Extrction of Independent variable & Dependent variable
#use .iloc[] function

X= data.iloc[:,0:3]
Y= data.iloc[:,3:4]

# %%
X.head()
# Out:
#    Country   Age        Salary
# 0   France  44.0  72000.000000
# 1    Spain  27.0  48000.000000
# 2  Germany  30.0  54000.000000
# 3    Spain  38.0  61000.000000
# 4     27.0  40.0  63777.777778

# %%
Y.head()
# Out:
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes

# %% [markdown]
# ![Screenshot 2026-04-16 140453.jpg](data:image/jpeg;base64,...)
# Handling Categoriccal Data
# 1) Lable encoding
# 2) OneHot encoding

# %%
#lable encoding
Y.replace(to_replace=["Yes","No"], value=[1,0])
# Out:
#    Purchased
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1
# 5          1
# 6          0
# 7          1
# 8          0
# 9          1

# %%
#onehot encoding
pd.get_dummies(X, dtype=int, drop_first=True)
# Out:
#          Age        Salary  Country_France  Country_Germany  Country_Spain
# 0  44.000000  72000.000000               1                0              0
# 1  27.000000  48000.000000               0                0              1
# 2  30.000000  54000.000000               0                1              0
# 3  38.000000  61000.000000               0                0              1
# 4  40.000000  63777.777778               0                0              0
# 5  35.000000  58000.000000               1                0              0
# 6  38.777778  52000.000000               0                0              1
# 7  48.000000  79000.000000               1                0              0
# 8  50.000000  83000.000000               0                1              0
# 9  37.000000  67000.000000               1                0              0

# %%
X
# Out:
#    Country        Age        Salary
# 0   France  44.000000  72000.000000
# 1    Spain  27.000000  48000.000000
# 2  Germany  30.000000  54000.000000
# 3    Spain  38.000000  61000.000000
# 4     27.0  40.000000  63777.777778
# 5   France  35.000000  58000.000000
# 6    Spain  38.777778  52000.000000
# 7   France  48.000000  79000.000000
# 8  Germany  50.000000  83000.000000
# 9   France  37.000000  67000.000000

# %%
Y
# Out:
#   Purchased
# 0        No
# 1       Yes
# 2        No
# 3        No
# 4       Yes
# 5       Yes
# 6        No
# 7       Yes
# 8        No
# 9       Yes

# %%
#Data Spliting(Compulsary)

# %%
#Feature Scaling(Optional)
